# %% [markdown]
# # 2020 Absorption Rates

# %% [markdown]
# Units Absorbed by Dwelling Type and Neighbourhood for Census Metropolitan Areas

# %% [markdown]
# Unabsorbed and Absorbed Tables need to be joined.

# %%
import pandas as pd

# %%
df = pd.read_csv('data/Neighborhood_Absorption.csv')

# %%
df.tail()
# Out:
#      Province   Centre                            Zone  \
# 56  Alta/Alb.  Calgary  Other Centres ~ Autres centres
# 57  Alta/Alb.  Calgary  Other Centres ~ Autres centres
# 58  Alta/Alb.  Calgary  Other Centres ~ Autres centres
# 59  Alta/Alb.  Calgary  Other Centres ~ Autres centres
# 60  Alta/Alb.  Calgary                           Total
#
#                         Neighbourhood\nQuartier Singles\nIndividuels  \
# 56                                      Airdrie                  522
# 57                                     Cochrane                  192
# 58  Calgary CMA Remainder ~ Calgary RMR (reste)                  311
# 59                                        Total                1,025
# 60                                        Total                3,904
#
#    Semis\nJumelés Row\nEn bande Apartment\nand Other\nAppartements\net autres  \
# 56            173           220                                             7
# 57            132            92                                             9
# 58             42            12                                             6
# 59            347           324                                            22
# 60          1,281         1,689                                         4,097
#
#      Total
# 56     922
# 57     425
# 58     371
# 59   1,718
# 60  10,971

# %%
df = df.drop(columns = ['Province', 'Centre'])
df.head()
# Out:
#                       Zone                        Neighbourhood\nQuartier  \
# 0  Downtown ~ Centre-ville  Downtown/Eau Claire ~ Centre-ville/Eau Claire
# 1  Downtown ~ Centre-ville                               Scarboro/Sunalta
# 2  Downtown ~ Centre-ville                                          Total
# 3                 Beltline                                Misson/Beltline
# 4                 Beltline               Lower Mount Royal/Cliff Bungalow
#
#   Singles\nIndividuels Semis\nJumelés Row\nEn bande  \
# 0                   --             --            --
# 1                    4              2            --
# 2                    4              2            --
# 3                   --             --            --
# 4                    5             --             1
#
#   Apartment\nand Other\nAppartements\net autres Total
# 0                                            73    73
# 1                                             3     9
# 2                                            76    82
# 3                                           464   464
# 4                                            --     6

# %%
df = df.rename(columns = {'Neighbourhood\nQuartier' : 'Neighbourhood', 'Singles\nIndividuels' : 'Singles', 'Semis\nJumelés' : 'Semis', 'Row\nEn bande' : 'Row', 'Apartment\nand Other\nAppartements\net autres' : 'Apartment_And_Other'
                    
                })

# %% [markdown]
# ### Breaking Down the Zones to Identify the Directional Sections in Accordance with the Map on Page 21

# %% [markdown]
# ### The Totals Will Need to be Removed From The DataFrame

# %% [markdown]
# The South East Industrial Neighborhood & Surrounding Communities will be grouped with South as it is predominately in the Southern region.

# %% [markdown]
# Airdrie will be removed as it is too far north.

# %%
df.head()
# Out:
#                       Zone                                  Neighbourhood  \
# 0  Downtown ~ Centre-ville  Downtown/Eau Claire ~ Centre-ville/Eau Claire
# 1  Downtown ~ Centre-ville                               Scarboro/Sunalta
# 2  Downtown ~ Centre-ville                                          Total
# 3                 Beltline                                Misson/Beltline
# 4                 Beltline               Lower Mount Royal/Cliff Bungalow
#
#   Singles Semis Row Apartment_And_Other Total
# 0      --    --  --                  73    73
# 1       4     2  --                   3     9
# 2       4     2  --                  76    82
# 3      --    --  --                 464   464
# 4       5    --   1                  --     6

# %%
df['Section'] = ''

# %%
df.Section[0:12] = 'Centre'

# %%
df.Section[12] = 'West'
df.Section[13] = 'Centre'
df.Section[14:19] = 'West'
df.Section[20:21] = 'East'
df.Section[22:24] = 'South'
df.Section[25] = 'North'
df.Section[26] = 'Centre'
df.Section[27] = 'Centre'
df.Section[28] = 'North'
df.Section[29] = 'Centre'
df.Section[30:38] = 'North'
df.Section[39:45] = 'East'
df.Section[46] = 'Centre'
df.Section[47] = 'Centre'
df.Section[48] = 'Centre'
df.Section[49] = 'South'
df.Section[51:55] = 'South'
df.Section[56:61] = 'None'

# %%
df.head(40)
# Out:
#                        Zone  \
# 0   Downtown ~ Centre-ville
# 1   Downtown ~ Centre-ville
# 2   Downtown ~ Centre-ville
# 3                  Beltline
# 4                  Beltline
# 5                  Beltline
# 6                  Beltline
# 7                North Hill
# 8                North Hill
# 9                North Hill
# 10               North Hill
# 11    Southwest ~ Sud-Ouest
# 12    Southwest ~ Sud-Ouest
# 13    Southwest ~ Sud-Ouest
# 14    Southwest ~ Sud-Ouest
# 15    Southwest ~ Sud-Ouest
# 16    Southwest ~ Sud-Ouest
# 17    Southwest ~ Sud-Ouest
# 18    Southwest ~ Sud-Ouest
# 19    Southwest ~ Sud-Ouest
# 20      Southeast ~ Sud-Est
# 21      Southeast ~ Sud-Est
# 22      Southeast ~ Sud-Est
# 23      Southeast ~ Sud-Est
# 24      Southeast ~ Sud-Est
# 25   Northwest ~ Nord-Ouest
# 26   Northwest ~ Nord-Ouest
# 27   Northwest ~ Nord-Ouest
# 28   Northwest ~ Nord-Ouest
# 29   Northwest ~ Nord-Ouest
# 30   Northwest ~ Nord-Ouest
# 31   Northwest ~ Nord-Ouest
# 32   Northwest ~ Nord-Ouest
# 33   Northwest ~ Nord-Ouest
# 34   Northwest ~ Nord-Ouest
# 35   Northwest ~ Nord-Ouest
# 36   Northwest ~ Nord-Ouest
# 37   Northwest ~ Nord-Ouest
# 38   Northwest ~ Nord-Ouest
# 39     Northeast ~ Nord-Est
#
#                                         Neighbourhood Singles Semis  Row  \
# 0       Downtown/Eau Claire ~ Centre-ville/Eau Claire      --    --   --
# 1                                    Scarboro/Sunalta       4     2   --
# 2                                               Total       4     2   --
# 3                                     Misson/Beltline      --    --   --
# 4                    Lower Mount Royal/Cliff Bungalow       5    --    1
# 5                                            Bankview       0     2    9
# 6                                               Total       5     2   10
# 7             Rosedale/Sunnyside/Crescent Hts/Renfrew      20    25    4
# 8                       Parkdale/St. Andrews Hts etc.      36    38    5
# 9                                Bridgeland/Riverside       7     3   14
# 10                                              Total      63    66   23
# 11  Altadore/South Calgary/CFB Currie etc. ~ Altad...      56    49   52
# 12                       North Glenmore Park/Lakeview      18    --    3
# 13                                Killarney/Glengarry      13    32   29
# 14              Wildwood/Spruce Cliff/Shaganappi etc.      15    12   20
# 15                                 Glendale/Glenbrook       2    19   --
# 16                             Rutland Park/Glamorgan       1    --   --
# 17           Strathcona Pk/Christie Pk/Patterson etc.       1     4   --
# 18           Valley Ridge/Crestmont/Cougar Ridge etc.     156     6   76
# 19                                              Total     262   122  180
# 20                    Forest Lawn/Forest Heights etc.       2    --   59
# 21               Dover/Southview/Inglewood/Alyth etc.       4     3   --
# 22  Southeast Industrial & Surrounding Comm. ~ Sec...       4     2   16
# 23                   McKenzie Towne/New Brighton etc.     497    83   87
# 24                                              Total     507    88  162
# 25                                            Bowness      14    12   31
# 26             Winston Hts/Mountview/Tuxedo Park etc.       6    25   30
# 27                                     Mount Pleasant       7    26   14
# 28             N Haven/Upper N Haven/Thorncliffe etc.      13    10   --
# 29                  Capitol Hill/Rosemont/Banff Trail      12    23   43
# 30              Montgomery/Point McKay/University Hts       7    15   40
# 31                  Charleswood/Collingwood/Brentwood      10    --   --
# 32                                            Varsity       8    --   --
# 33                                          Dalhousie       5    --   --
# 34                Silver Springs/Scenic Acres/Tuscany       2    --    4
# 35                   Ranchlands/Hawkwood/Citadel etc.      19    --    4
# 36                 Sherwood/Kincora/Hamptons/Edgemont     152    10   64
# 37                     Huntington Hills/Evanston etc.     565   188  252
# 38                                              Total     820   309  482
# 39            Vista Heights/Skyline East/Pegasus etc.       1     4   --
#
#    Apartment_And_Other  Total Section
# 0                   73     73  Centre
# 1                    3      9  Centre
# 2                   76     82  Centre
# 3                  464    464  Centre
# 4                   --      6  Centre
# 5                   21     32  Centre
# 6                  485    502  Centre
# 7                   13     62  Centre
# 8                  106    185  Centre
# 9                   73     97  Centre
# 10                 192    344  Centre
# 11                 194    351  Centre
# 12                   2     23    West
# 13                  36    110  Centre
# 14                   9     56    West
# 15                   1     22    West
# 16                  --      1    West
# 17                  26     31    West
# 18                 175    413    West
# 19                 443  1,007
# 20                  10     71    East
# 21                 122    129    East
# 22                  39     61   South
# 23                 621  1,288   South
# 24                 792  1,549
# 25                  45    102   North
# 26                   6     67  Centre
# 27                   6     53  Centre
# 28                   2     25   North
# 29                   5     83  Centre
# 30                 709    771   North
# 31                 165    175   North
# 32                  --      8   North
# 33                  --      5   North
# 34                  --      6   North
# 35                   5     28   North
# 36                 146    372   North
# 37                 185  1,190   North
# 38               1,274  2,885
# 39                   1      6    East

# %%
df = df[df['Neighbourhood'] != 'Total']

# %%
df.shape
# Out:
# (50, 8)

# %%
df.head()
# Out:
#                       Zone                                  Neighbourhood  \
# 0  Downtown ~ Centre-ville  Downtown/Eau Claire ~ Centre-ville/Eau Claire
# 1  Downtown ~ Centre-ville                               Scarboro/Sunalta
# 3                 Beltline                                Misson/Beltline
# 4                 Beltline               Lower Mount Royal/Cliff Bungalow
# 5                 Beltline                                       Bankview
#
#   Singles Semis Row Apartment_And_Other Total Section
# 0      --    --  --                  73    73  Centre
# 1       4     2  --                   3     9  Centre
# 3      --    --  --                 464   464  Centre
# 4       5    --   1                  --     6  Centre
# 5       0     2   9                  21    32  Centre

# %%
n_df = df[df['Section'] == 'North']
s_df = df[df['Section'] == 'South']
e_df = df[df['Section'] == 'East']
w_df = df[df['Section'] == 'West']
c_df = df[df['Section'] == 'Centre']

# %% [markdown]
# ### The Neighborhoods are Sorted Into Sections

# %% [markdown]
# The data needs to be further sorted into averages for each property type.

# %%
n_df.head()
# Out:
#                       Zone                           Neighbourhood Singles  \
# 25  Northwest ~ Nord-Ouest                                 Bowness      14
# 28  Northwest ~ Nord-Ouest  N Haven/Upper N Haven/Thorncliffe etc.      13
# 30  Northwest ~ Nord-Ouest   Montgomery/Point McKay/University Hts       7
# 31  Northwest ~ Nord-Ouest       Charleswood/Collingwood/Brentwood      10
# 32  Northwest ~ Nord-Ouest                                 Varsity       8
#
#    Semis Row Apartment_And_Other Total Section
# 25    12  31                  45   102   North
# 28    10  --                   2    25   North
# 30    15  40                 709   771   North
# 31    --  --                 165   175   North
# 32    --  --                  --     8   North

# %%
unabsorbed = pd.read_csv('data/Units_Unabsorbed_Neighbourhoods.csv')

# %%
unabsorbed.head()
# Out:
#     Province   Centre                     Zone  \
# 0  Alta/Alb.  Calgary  Downtown ~ Centre-ville
# 1  Alta/Alb.  Calgary  Downtown ~ Centre-ville
# 2  Alta/Alb.  Calgary  Downtown ~ Centre-ville
# 3  Alta/Alb.  Calgary                 Beltline
# 4  Alta/Alb.  Calgary                 Beltline
#
#                          Neighbourhood\nQuartier Singles\nIndividuels  \
# 0  Downtown/Eau Claire ~ Centre-ville/Eau Claire                   --
# 1                               Scarboro/Sunalta                    0
# 2                                          Total                    0
# 3                                Misson/Beltline                   --
# 4               Lower Mount Royal/Cliff Bungalow                    1
#
#   Semis\nJumelés Row\nEn bande Apartment\nand Other\nAppartements\net autres  \
# 0             --            --                                            81
# 1              2            --                                            --
# 2              2            --                                            81
# 3             --            --                                            --
# 4             --            --                                            --
#
#   Total
# 0    81
# 1     2
# 2    83
# 3    --
# 4     1

# %%
sw_df = df[df['Zone'] == 'Southwest ~ Sud-Ouest']

# %%
sw_df.head(10)
# Out:
#                      Zone                                      Neighbourhood  \
# 11  Southwest ~ Sud-Ouest  Altadore/South Calgary/CFB Currie etc. ~ Altad...
# 12  Southwest ~ Sud-Ouest                       North Glenmore Park/Lakeview
# 13  Southwest ~ Sud-Ouest                                Killarney/Glengarry
# 14  Southwest ~ Sud-Ouest              Wildwood/Spruce Cliff/Shaganappi etc.
# 15  Southwest ~ Sud-Ouest                                 Glendale/Glenbrook
# 16  Southwest ~ Sud-Ouest                             Rutland Park/Glamorgan
# 17  Southwest ~ Sud-Ouest           Strathcona Pk/Christie Pk/Patterson etc.
# 18  Southwest ~ Sud-Ouest           Valley Ridge/Crestmont/Cougar Ridge etc.
# 19  Southwest ~ Sud-Ouest                                              Total
#
#    Singles Semis  Row Apartment_And_Other  Total
# 11      56    49   52                 194    351
# 12      18    --    3                   2     23
# 13      13    32   29                  36    110
# 14      15    12   20                   9     56
# 15       2    19   --                   1     22
# 16       1    --   --                  --      1
# 17       1     4   --                  26     31
# 18     156     6   76                 175    413
# 19     262   122  180                 443  1,007
